# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
norm = np.load("/home/gmh72/3DReconstruction/indoor_scene/Scenecut_NeuRIS/dependencies/surface_normal_uncertainty/examples/test_sample/results/scannet-10.npz")["arr_0"]

# %%
norm.shape
# Out:
# (480, 640, 3)

# %%
plt.imshow(norm)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
norm_1= np.load("/home/gmh72/3DReconstruction/indoor_scene/Scenecut_NeuRIS/dataset/indoor/replica_room0/pred_normal/0000.npz")["arr_0"]
norm_1.shape
# Out:
# (480, 640, 3)

# %%
plt.imshow(norm_1)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
